# %%
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %%
#### Plotting a set of points in 3D

fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(111, projection='3d')

X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
print("original: ", X.shape, Y.shape)
X, Y = np.meshgrid(X, Y)
print("after meshgrid: ", X.shape, Y.shape)

### The 3D function
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

### plotting a scatter plot, play with the color and size of the points as well as the alpha
ax.scatter(X, Y, Z)  

# add labels to the axis

plt.show()
# Out:
# original:  (40,) (40,)
# after meshgrid:  (40, 40) (40, 40)

# %%
# Changing the size of the plot
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(111, projection='3d')

X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

### plotting the surface of a function, once again play with color, and alpha values
ax.plot_surface(X, Y, Z)  

# add labels to the axis


plt.show()

# %%
# We are now going to plot the colors of the surface in x and y
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(111)

# plotting the contour plot, play with different color maps
contour = ax.contour(X, Y, Z, cmap="Greys") # cool, plasma

# add a colorbar

# add labels to the axis

plt.show()

# %%
# Now we fill in that contour plot
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(111)

# plotting a filled contour, make sure to play around with the colormap and the alpha
contour = ax.contourf(X, Y, Z,cmap="viridis")

# add a colorbar

# label the axis

plt.show()

# %%
# Challenge: Plot a 3D surface plot and filled contour plot for the same R but with Z = cos(R)
# play around with the number of levels for the contour plot
